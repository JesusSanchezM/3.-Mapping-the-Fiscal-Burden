# %%
# libraries
import pandas as pd
import numpy as np
import sys
from pathlib import Path

# -----------------------------------------------------
# PATH CONFIGURATION
# -----------------------------------------------------
ROOT = Path.cwd().parent
sys.path.append(str(ROOT))

from config.paths import RAW_DIR, PROCESSED_DIR

# %%
DATA_PATH = ROOT / 'data' / 'raw' / 'trabajos_2018.csv'
df = pd.read_csv(DATA_PATH)
print(df.head())
# Out:
#     folioviv  foliohog  numren  id_trabajo  trapais  subor indep personal  \
# 0  100013601         1       1           1        1      1
# 1  100013601         1       3           1        1      1
# 2  100013602         1       1           1        1      2     1        2
# 3  100013602         1       3           1        1      2     1        2
# 4  100013603         1       1           1        1      1
#
#   pago contrato  ... tipoact4 lugar conf_pers medtrab_1 medtrab_2 medtrab_3  \
# 0    1        1  ...
# 1    1        2  ...
# 2                ...
# 3                ...
# 4    1        1  ...                                  1
#
#   medtrab_4 medtrab_5 medtrab_6 medtrab_7
# 0                                       7
# 1                                       7
# 2
# 3
# 4
#
# [5 rows x 56 columns]

# %%
df["pres_8"].value_counts()
# Out:
# pres_8
#       106570
# 08     33363
# Name: count, dtype: int64

# %%
df["pres_8"].dtypes
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df.dtypes
# Out:
# folioviv      int64
# foliohog      int64
# numren        int64
# id_trabajo    int64
# trapais       int64
# subor         int64
# indep           str
# personal        str
# pago            str
# contrato        str
# tipocontr       str
# pres_1          str
# pres_2          str
# pres_3          str
# pres_4          str
# pres_5          str
# pres_6          str
# pres_7          str
# pres_8          str
# pres_9          str
# pres_10         str
# pres_11         str
# pres_12         str
# pres_13         str
# pres_14         str
# pres_15         str
# pres_16         str
# pres_17         str
# pres_18         str
# pres_19         str
# pres_20         str
# htrab         int64
# sinco         int64
# scian         int64
# clas_emp        str
# tam_emp       int64
# no_ing          str
# tiene_suel      str
# tipoact         str
# socios          str
# soc_nr1         str
# soc_nr2         str
# soc_resp        str
# otra_act        str
# tipoact2        str
# ...

# %%
DATA_PATH = ROOT / 'data' / 'raw' / 'trabajos_2024.csv'
df = pd.read_csv(DATA_PATH)
df.dtypes
# Out:
# folioviv        int64
# foliohog        int64
# numren          int64
# id_trabajo      int64
# trapais         int64
# subor           int64
# indep         float64
# personal      float64
# pago          float64
# contrato      float64
# tipocontr     float64
# pres_1        float64
# pres_2        float64
# pres_3        float64
# pres_4        float64
# pres_5        float64
# pres_6        float64
# pres_7        float64
# pres_8        float64
# pres_9        float64
# pres_10       float64
# pres_11       float64
# pres_12       float64
# pres_13       float64
# pres_14       float64
# pres_15       float64
# pres_16       float64
# pres_17       float64
# pres_18       float64
# pres_19       float64
# pres_20       float64
# htrab           int64
# sinco           int64
# scian           int64
# clas_emp      float64
# tam_emp         int64
# no_ing        float64
# tiene_suel    float64
# tipoact       float64
# socios            str
# soc_nr1           str
# ...

# %%
DATA_PATH = ROOT / 'data' / 'processed' / 'income_fiscal_incidence_base.csv'
df = pd.read_csv(DATA_PATH)
df.dtypes
# Out:
# folioviv                  int64
# foliohog                  int64
# numren                    int64
# year                      int64
# net_trabajo1_ann        float64
# net_trabajo2_ann        float64
# isr_total               float64
# formal_trabajo_1        float64
# formal_trabajo_2        float64
# mi_trabajo_1            float64
# mi_trabajo_2            float64
# mi_capital              float64
# mi_private_transfers    float64
# market_income           float64
# net_market_income       float64
# di_direct_transfers     float64
# disposable_income       float64
# dtype: object
